# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('hr_data.csv')
#data.head()
data_select = data[['model_number', 'luminosity']]






#dataselected = data['luminosity', 'log_L']

#dataselected.plot()


#plt.show()






#headers = data.dtypes.index
# Out:
#        model_number  luminosity
# 0               610       0.916
# 1               611       0.916
# 2               612       0.916
# 3               613       0.915
# 4               614       0.915
# 5               615       0.915
# 6               616       0.915
# 7               617       0.915
# 8               618       0.915
# 9               619       0.914
# 10              620       0.914
# 11              621       0.913
# 12              622       0.913
# 13              623       0.912
# 14              624       0.912
# 15              625       0.911
# 16              626       0.910
# 17              627       0.909
# 18              628       0.907
# 19              629       0.906
# 20              630       0.904
# 21              631       0.902
# 22              632       0.900
# 23              633       0.897
# 24              634       0.895
# 25              635       0.892
# 26              636       0.889
# 27              637       0.887
# ...
